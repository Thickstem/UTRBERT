# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.dpi"]=300

# %%
import glob
import os
files = glob.glob("./Bothprime_upper30_cds15/*importance*")
print(files)
# Out:
# ['./Bothprime_upper30_cds15/pc3_lgb_cv0_importance.csv', './Bothprime_upper30_cds15/hek_rf_cv0_importance.csv', './Bothprime_upper30_cds15/hek_lgb_cv0_importance.csv', './Bothprime_upper30_cds15/pc3_rf_cv0_importance.csv']

# %%
id=3
print(os.path.basename(files[id]))
imp_df = pd.read_csv(files[id])
# Out:
# pc3_rf_cv0_importance.csv

# %%
tops = imp_df.iloc[:25]
plt.barh(tops["feature"][::-1],tops["importance"][::-1],align="center")
plt.yticks(tops["feature"],fontsize=7)
plt.title("5'UTR+3'UTR PC3 LGB (top 25)")
plt.xlabel("importance")
plt.tight_layout()
plt.savefig("/home/ksuga/UTRBERT/Feature_eng/results/importance_5'UTR+3'UTR PC3 RF",facecolor="white")
